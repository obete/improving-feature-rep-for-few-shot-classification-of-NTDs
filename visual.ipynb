# %% [markdown]
# The next Cells, training results progression for the top four models. namey vit16b, vit32b, DenseNet161, VGG16_bn.

# %%
#import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# Reading and importing the data from csv
#LOG_URL = "D:/MSCS_Research/Output/Fitzpatrick17k_Evalutaion"
LOG_URL = "D:/MSCS_Research/Output/SD198_evaluation"

# %% [markdown]
# Comparison of Training Matrices of the top 4 performaers during evalutaion.

# %%
#Weight_F1 =f'{LOG_URL}/WF1_Comparison.CSV'
#Val_Accuracy =f'{LOG_URL}/Val_Acc_Comparison.CSV'
Training_Loss =f'{LOG_URL}/Train_Loss_Comparison.CSV'

#df = pd.read_csv(Weight_F1)
#df = pd.read_csv(Val_Accuracy)
df = pd.read_csv(Training_Loss)

x = df["Epoch"]
ViT_b_16 = df["ViT_b_16"]
ViT_b_32 = df["ViT_b_32"]
DenseNet161 = df["DenseNet161"]
VGG16 = df["VGG16"]
EfficientNet_b0 = df["EfficientNet_b0"]
EfficientNet_b1 = df["EfficientNet_b1"]
MobileNet_v2 = df["MobileNet_v2"]
VGG16_bn = df["VGG16_bn"]
ResNet50 = df["ResNet50"]
#Configuring the axes
plt.plot(x, ViT_b_16, label = "vit_b_16", color="Blue", linestyle="-", marker="" )
plt.plot(x, ViT_b_32, label = "vit_b_32", color="Red", linestyle="-", marker="" )
plt.plot(x, DenseNet161, label = "denseet161", color="Green", linestyle="-", marker="" )
plt.plot(x, VGG16, label = "vgg16", color="Purple", linestyle="-", marker="" )
plt.plot(x, VGG16_bn, label = "vgg16_bn", color="Yellow", linestyle="-", marker="" )
plt.plot(x, EfficientNet_b0, label = "EfficientNet_b0", color="Violet", linestyle="-", marker="" )
plt.plot(x, EfficientNet_b1, label = "efficientnet_b1", color="Cyan", linestyle="-", marker="" )
plt.plot(x, MobileNet_v2, label = "mobilenet_v2", color="Grey", linestyle="-", marker="" )
plt.plot(x, ResNet50, label = "resnet50", color="Black", linestyle="-", marker="" )
#Addding elements of the plot
plt.title("Training Loss Comparison on SD-198 Dermatology Dataset")
plt.xlabel("Epoch")
plt.ylabel("")
plt.legend()
plt.grid(True)
#Displaying
plt.show()
